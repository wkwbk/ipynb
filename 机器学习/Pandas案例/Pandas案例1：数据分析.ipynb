# %% [markdown]
# # 案例1: 使用Pandas分析近600万条图书评分数据

# %% [markdown]
# ### 1. 读取数据

# %%
import pandas as pd

data=pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Pandas案例/rating.txt')
data
# Out:
#              1   258  5
# 0            2  4081  4
# 1            2   260  5
# 2            2  9296  5
# 3            2  2318  3
# 4            2    26  4
# ...        ...   ... ..
# 5976473  49925   510  5
# 5976474  49925   528  4
# 5976475  49925   722  4
# 5976476  49925   949  5
# 5976477  49925  1023  4
#
# [5976478 rows x 3 columns]

# %%
import pandas as pd
data=pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Pandas案例/rating.txt',header=None)
data
# Out:
#              0     1  2
# 0            1   258  5
# 1            2  4081  4
# 2            2   260  5
# 3            2  9296  5
# 4            2  2318  3
# ...        ...   ... ..
# 5976474  49925   510  5
# 5976475  49925   528  4
# 5976476  49925   722  4
# 5976477  49925   949  5
# 5976478  49925  1023  4
#
# [5976479 rows x 3 columns]

# %%
import pandas as pd

data=pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Pandas案例/rating.txt',header=None,names=['读者ID','图书ID','评分'])
data
# Out:
#           读者ID  图书ID  评分
# 0            1   258   5
# 1            2  4081   4
# 2            2   260   5
# 3            2  9296   5
# 4            2  2318   3
# ...        ...   ...  ..
# 5976474  49925   510   5
# 5976475  49925   528   4
# 5976476  49925   722   4
# 5976477  49925   949   5
# 5976478  49925  1023   4
#
# [5976479 rows x 3 columns]

# %% [markdown]
# ### 2. 筛选数据

# %%
data
# Out:
#           读者ID  图书ID  评分
# 0            1   258   5
# 1            2  4081   4
# 2            2   260   5
# 3            2  9296   5
# 4            2  2318   3
# ...        ...   ...  ..
# 5976474  49925   510   5
# 5976475  49925   528   4
# 5976476  49925   722   4
# 5976477  49925   949   5
# 5976478  49925  1023   4
#
# [5976479 rows x 3 columns]

# %%
data['图书ID']==260
# Out:
# 0          False
# 1          False
# 2           True
# 3          False
# 4          False
#            ...
# 5976474    False
# 5976475    False
# 5976476    False
# 5976477    False
# 5976478    False
# Name: 图书ID, Length: 5976479, dtype: bool

# %%
data[data['图书ID']==260]
# Out:
#           读者ID  图书ID  评分
# 2            2   260   5
# 9270       401   260   3
# 12722      533   260   4
# 48584     1642   260   4
# 53818     1810   260   4
# ...        ...   ...  ..
# 5955797  18651   260   4
# 5968206  10823   260   4
# 5971536  26813   260   4
# 5973048  34908   260   4
# 5975862    565   260   4
#
# [1767 rows x 3 columns]

# %%
data[data['图书ID']==260]['评分']
# Out:
# 2          5
# 9270       3
# 12722      4
# 48584      4
# 53818      4
#           ..
# 5955797    4
# 5968206    4
# 5971536    4
# 5973048    4
# 5975862    4
# Name: 评分, Length: 1767, dtype: int64

# %%
data[data['图书ID']==260]['评分'].sum()
# Out:
# np.int64(6882)

# %%
data[data['图书ID']==260]['评分'].sum()/1767
# Out:
# np.float64(3.8947368421052633)

# %%
data[data['图书ID']==260]['评分'].mean()
# Out:
# np.float64(3.8947368421052633)

# %% [markdown]
# ### 3. 分组统计

# %%
data.groupby('图书ID')

# %%
data.groupby('图书ID')['评分']

# %%
data.groupby('图书ID')['评分'].mean()
# Out:
# 图书ID
# 1        4.279707
# 2        4.351350
# 3        3.214341
# 4        4.329369
# 5        3.772224
#            ...
# 9996     4.014184
# 9997     4.451613
# 9998     4.323529
# 9999     3.707692
# 10000    4.009009
# Name: 评分, Length: 10000, dtype: float64

# %% [markdown]
# ### 统计每本书平均分的完整程序：

# %%
import pandas as pd

data=pd.read_csv('/content/drive/MyDrive/Colab Notebooks/test.ipynb',header=None,names=['读者ID','图书ID','评分'])
result=data.groupby('图书ID')['评分'].mean()
result
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/pandas/core/groupby/groupby.py in _agg_py_fallback(self, how, values, ndim, alt)
#    1941         try:
# -> 1942             res_values = self._grouper.agg_series(ser, alt, preserve_dtype=True)
#    1943         except Exception as err:
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/groupby/ops.py in agg_series(self, obj, func, preserve_dtype)
#     863
# --> 864         result = self._aggregate_series_pure_python(obj, func)
#     865
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/groupby/ops.py in _aggregate_series_pure_python(self, obj, func)
#     884         for i, group in enumerate(splitter):
# --> 885             res = func(group)
#     886             res = extract_result(res)
#
# ...
