# %% [markdown]
# # 豆瓣Top250爬取

# %%
from bs4 import BeautifulSoup
import requests

headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/110.0.0.0 Safari/537.36 Edg/110.0.1587.63"
}

for start_num in range(0, 250, 25):

    url = f"https://movie.douban.com/top250?start={start_num}"

    response = requests.get(url, headers=headers)
    html = response.text
    soup = BeautifulSoup(html, "html.parser")
    all_title = soup.findAll("span", attrs={"class": "title"})

    for title in all_title:
        title_string = title.string
        if "/" not in title_string:
            print(title_string)
# Out:
# <ipython-input-1-4616674f0624>:15: DeprecationWarning: Call to deprecated method findAll. (Replaced by find_all) -- Deprecated since version 4.0.0.
#   all_title = soup.findAll("span", attrs={"class": "title"})
# 肖申克的救赎
# 霸王别姬
# 泰坦尼克号
# 阿甘正传
# 千与千寻
# 美丽人生
# 这个杀手不太冷
# 星际穿越
# 盗梦空间
# 楚门的世界
# 辛德勒的名单
# 忠犬八公的故事
# 海上钢琴师
# 三傻大闹宝莱坞
# 疯狂动物城
# 放牛班的春天
# 机器人总动员
# 无间道
# 控方证人
# 大话西游之大圣娶亲
# 熔炉
# 触不可及
# 教父
# 寻梦环游记
# 当幸福来敲门
# 末代皇帝
# 龙猫
# 哈利·波特与魔法石
# 怦然心动
# 活着
# 蝙蝠侠：黑暗骑士
# 指环王3：王者无敌
# 我不是药神
# 乱世佳人
# 飞屋环游记
# 让子弹飞
# 哈尔的移动城堡
# 素媛
# 十二怒汉
# 海蒂和爷爷
# 猫鼠游戏
# 天空之城
# 摔跤吧！爸爸
# 鬼子来了
# 少年派的奇幻漂流
# 钢琴家
# 指环王2：双塔奇兵
# 大话西游之月光宝盒
# 死亡诗社
# 何以为家
# 闻香识女人
# 绿皮书
# 大闹天宫
# 黑客帝国
# 罗马假日
# 指环王1：护戒使者
# 教父2
# 狮子王
# 天堂电影院
# 饮食男女
# 辩护人
# 搏击俱乐部
# 本杰明·巴顿奇事
# 美丽心灵
# 穿条纹睡衣的男孩
# 情书
# 窃听风暴
# 两杆大烟枪
# 哈利·波特与死亡圣器(下)
# 音乐之声
# 西西里的美丽传说
# 阿凡达
# 功夫
# 看不见的客人
# 哈利·波特与阿兹卡班的囚徒
# 拯救大兵瑞恩
# 小鞋子
# 沉默的羔羊
# 飞越疯人院
# 布达佩斯大饭店
# 蝴蝶效应
# 禁闭岛
# 致命魔术
# 心灵捕手
# 低俗小说
# 超脱
# 哈利·波特与密室
# 摩登时代
# 喜剧之王
# 致命ID
# 杀人回忆
# 春光乍泄
# 海豚湾
# 一一
# 美国往事
# 加勒比海盗
# 红辣椒
# 七宗罪
# 唐伯虎点秋香
# 狩猎
# 甜蜜蜜
# 7号房的礼物
# 蝙蝠侠：黑暗骑士崛起
# 寄生虫
# 天书奇谭
# 超能陆战队
# 被嫌弃的松子的一生
# 爱在黎明破晓前
# 第六感
# 重庆森林
# 爱在日落黄昏时
# 幽灵公主
# 还有明天
# 入殓师
# 剪刀手爱德华
# 断背山
# 菊次郎的夏天
# 勇敢的心
# 未麻的部屋
# 哈利·波特与火焰杯
# 借东西的小人阿莉埃蒂
# 茶馆
# 消失的爱人
# 时空恋旅人
# 头脑特工队
# 无人知晓
# 倩女幽魂
# 阳光灿烂的日子
# 完美的世界
# 天使爱美丽
# 小森林 夏秋篇
# 驯龙高手
# 花样年华
# 新世界
# 侧耳倾听
# 傲慢与偏见
# 请以你的名字呼唤我
# 怪兽电力公司
# 一个叫欧维的男人决定去死
# 玩具总动员3
# 教父3
# 幸福终点站
# 色，戒
# 哪吒闹海
# 小森林 冬春篇
# 被解救的姜戈
# 九品芝麻官
# 釜山行
# 神偷奶爸
# 萤火之森
# 告白
# 喜宴
# 头号玩家
# 玛丽和马克思
# 模仿游戏
# 大鱼
# 七武士
# 惊魂记
# 射雕英雄传之东成西就
# 我是山姆
# 血战钢锯岭
# 你的名字。
# 阳光姐妹淘
# 恐怖直播
# 黑客帝国3：矩阵革命
# 背靠背，脸对脸
# 电锯惊魂
# 三块广告牌
# 心灵奇旅
# 小丑
# 达拉斯买家俱乐部
# 谍影重重3
# 疯狂原始人
# 绿里奇迹
# 无间道2
# 爱在午夜降临前
# 海街日记
# 上帝之城
# 英雄本色
# 风之谷
# 疯狂的石头
# 心迷宫
# 雨中曲
# 2001太空漫游
# 纵横四海
# 记忆碎片
# 卢旺达饭店
# 末路狂花
# 无敌破坏王
# 小偷家族
# 冰川时代
# 高山下的花环
# 牯岭街少年杀人事件
# 恐怖游轮
# 东京教父
# 岁月神偷
# 忠犬八公物语
# 魔女宅急便
# 荒蛮故事
# 遗愿清单
# 大佛普拉斯
# 贫民窟的百万富翁
# 东邪西毒
# 源代码
# 你看起来好像很好吃
# 疯狂的麦克斯4：狂暴之路
# 芙蓉镇
# 可可西里
# 爆裂鼓手
# 城市之光
# 波西米亚狂想曲
# 花束般的恋爱
# 黑天鹅
# 青蛇
# 爱乐之城
# 白日梦想家
# 哈利·波特与死亡圣器(上)
# 终结者2：审判日
# 初恋这件小事
# 雨人
# 人工智能
# 新龙门客栈
# 无耻混蛋
# 虎口脱险
# 真爱至上
# 崖上的波妞
# 恋恋笔记本
# 罗生门
# 千钧一发
# 大红灯笼高高挂
# 彗星来的那一夜
# 哈利·波特与凤凰社
# 海边的曼彻斯特
# 火星救援
# 黑客帝国2：重装上阵
# 萤火虫之墓
# 奇迹男孩
# 机器人之梦
# 战争之王
# 千年女优
# 步履不停
# 血钻
# 谍影重重2
# 蜘蛛侠：平行宇宙
# 魂断蓝桥
# 房间
# 冰雪奇缘
# 隐藏人物
# 谍影重重
# 弱点
