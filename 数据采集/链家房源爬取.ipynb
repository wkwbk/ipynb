# %% [markdown]
# # 链家房源爬取

# %%
import time
import csv
import requests
from lxml import etree

# 常量定义
USER_AGENT = "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36"
BASE_URL = "https://bj.lianjia.com/zufang/chaoyang/pg"
CSV_FILE = "朝阳区租房信息.csv"


def get_data(base_url, page_num):
    data_list = []
    session = requests.Session()
    session.headers.update({"User-Agent": USER_AGENT})
    for i in range(0, page_num):
        print(f"准备爬取第 {i + 1} 页......")
        count = 0
        url = base_url + str(i + 1)
        html = ask_url(url, session)
        if not html:
            print(f"跳过第 {i + 1} 页，无法获取页面内容。")
            continue
        tree = etree.HTML(html)
        items = tree.xpath('//div[@class="content__list--item--main"]')

        for item in items:
            data = []
            try:
                link = item.xpath('.//p[@class="content__list--item--title"]/a/@href')
                link = 'https://bj.lianjia.com' + link[0] if link else "未知"
                street = item.xpath('.//p[@class="content__list--item--des"]/a/text()')
                street = street[1] if len(street) > 1 else "未知"
                area = item.xpath('.//p[@class="content__list--item--des"]/a/@title')
                area = area[0] if area else "未知"
                price = item.xpath('.//span[@class="content__list--item-price"]/em/text()')
                price = price[0] if price else "未知"
                text = item.xpath('.//p[@class="content__list--item--des"]/text()')
                size = next((s.replace('<i>/</i>', '').replace('㎡', '').strip() for s in text if '㎡' in s), "未知")
                orientation = next((s.replace('<i>/</i>', '').strip() for s in text if '室' in s and '厅' in s), "未知")
                layout = next((s.replace('<i>/</i>', '').replace(' ', '').strip() for s in text if '南' in s or '北' in s or '东' in s or '西' in s), "未知")

                data.append(link)
                data.append(street)
                data.append(area)
                data.append(size)
                data.append(price)
                data.append(layout)
                data.append(orientation)

                if "未知" not in data:
                    print(data)
                    data_list.append(data)
                    count += 1

            except Exception as e:
                print(f"处理房源信息时出错: {e}") # 打印更详细的错误信息

        print(f"本页共爬取到 {count} 条有效数据。")
        print("---------------------------")

    return data_list


def ask_url(url, session):  # 添加 session 参数
    print("正在获取页面内容......")
    try:
        response = session.get(url, timeout=10)  # 使用 session 发送请求, 添加超时
        response.raise_for_status()  # 检查HTTP状态码，如果不是200，抛出异常
        html = response.text
        time.sleep(10)
        return html
    except requests.exceptions.RequestException as e:  # 捕获更广泛的 requests 异常
        print(f"请求失败: {e}")
        return ""


def save_data(data_list, save_path):
    col = ["URL", "街道", "小区", "面积", "价格", "朝向", "户型"]
    # 使用集合去除重复数据，以URL为键
    unique_data = []
    seen_urls = set()
    for data in data_list:
        url = data[0]  # URL是列表中的第一个元素
        if url not in seen_urls:
            unique_data.append(data)
            seen_urls.add(url)
    print(f"去重后还有 {len(unique_data)} 条数据。")
    print("正在保存到 CSV 文件中......")
    with open(save_path, "w", encoding='utf-8-sig', newline='') as csvfile:
        writer = csv.writer(csvfile)
        writer.writerow(col)
        for data in unique_data:
            writer.writerow(data)
    print("数据已成功保存到 CSV 文件。")


if __name__ == '__main__':
    datalist = get_data(BASE_URL, 5)
    print(f"共爬取到 {len(datalist)} 条有效数据。")
    save_data(datalist, CSV_FILE)
# Out:
# 准备爬取第 1 页......
# 正在获取页面内容......
# ['https://bj.lianjia.com/zufang/BJ2017854914570485760.html', '西坝河', '柳芳北街9号院', '65.46', '7000', '南', '2室1厅1卫']
# ['https://bj.lianjia.com/zufang/BJ2017856979782860800.html', '劲松', '广和东里', '50.12', '4800', '南', '2室1厅1卫']
# ['https://bj.lianjia.com/zufang/BJ2017470177750286336.html', '四惠', '通惠家园', '74.93', '6200', '南', '2室1厅1卫']
# ['https://bj.lianjia.com/zufang/BJ2017836510342021120.html', '常营', '筑福家园', '77.43', '5900', '南', '2室1厅1卫']
# ['https://bj.lianjia.com/zufang/BJ2015340131656925184.html', '高碑店', '南太平庄北巷', '64.36', '3500', '南北', '2室1厅1卫']
# ['https://bj.lianjia.com/zufang/BJ2017145847808000000.html', '国展', '左家庄东里', '63.09', '6200', '南', '2室1厅1卫']
# ['https://bj.lianjia.com/zufang/BJ1840010743072686080.html', '朝青', '晴悦家园', '80.48', '6800', '南', '2室1厅1卫']
# ['https://bj.lianjia.com/zufang/BJ2011289186778218496.html', '工体', '杰座大厦', '71.56', '9000', '东', '1室1厅1卫']
# ['https://bj.lianjia.com/zufang/BJ2017169778463997952.html', '望京', '融科橄榄城一期', '153.91', '19000', '南北', '3室2厅2卫']
# ['https://bj.lianjia.com/zufang/BJ2016753799732920320.html', '南沙滩', '北沙滩1号院', '130.00', '11000', '南北', '3室1厅1卫']
# ['https://bj.lianjia.com/zufang/BJ2017838878685134848.html', '劲松', '农光里', '64.00', '5950', '南北', '2室1厅1卫']
# ['https://bj.lianjia.com/zufang/BJ2017196331830870016.html', '中央别墅区', '瑞平家园', '61.98', '5600', '南', '1室1厅1卫']
# ['https://bj.lianjia.com/zufang/BJ2014632571387772928.html', '国展', '静安里', '60.00', '6200', '南北', '2室1厅1卫']
# ['https://bj.lianjia.com/zufang/BJ2017137744932765696.html', '望京', '华樾北京一期', '88.42', '9600', '南北', '3室2厅1卫']
# ['https://bj.lianjia.com/zufang/BJ2016047714478850048.html', '太阳宫', '冠城大通澜石', '114.81', '17500', '南北', '2室1厅2卫']
# ['https://bj.lianjia.com/zufang/BJ1847464607396921344.html', '双井', '苹果社区南区', '94.21', '9500', '西北', '2室1厅1卫']
# ['https://bj.lianjia.com/zufang/BJ2013112843032854528.html', '甘露园', '天天朝阳', '38.12', '4300', '东', '1室1厅1卫']
# ['https://bj.lianjia.com/zufang/BJ2013114892734693376.html', '东直门', '新源西里东街', '59.00', '8500', '东南南', '3室1厅1卫']
# ['https://bj.lianjia.com/zufang/BJ2013123769245106176.html', '双井', '世桥国贸', '115.00', '11000', '东西', '2室1厅1卫']
# ['https://bj.lianjia.com/zufang/BJ2013127773190619136.html', '石佛营', '石佛营西里小区', '47.52', '4800', '南北', '1室1厅1卫']
# ['https://bj.lianjia.com/zufang/BJ2013127183916072960.html', '双井', '时代国际嘉园', '99.87', '10000', '南北', '2室1厅1卫']
# ['https://bj.lianjia.com/zufang/BJ1887899810262941696.html', '惠新西街', '城市出品', '56.00', '6600', '东', '1室1厅1卫']
# ['https://bj.lianjia.com/zufang/BJ2013138863911862272.html', '红庙', '禧瑞都', '175.00', '33000', '西南', '3室2厅2卫']
# ['https://bj.lianjia.com/zufang/BJ2013147751591706624.html', '东坝', '首开常青藤二期', '152.02', '12000', '南北', '3室2厅2卫']
# ['https://bj.lianjia.com/zufang/BJ2013151735350034432.html', '建国门外', '灵通观', '62.35', '9200', '南北', '2室1厅1卫']
# 本页共爬取到 25 条有效数据。
# ---------------------------
# 准备爬取第 2 页......
# 正在获取页面内容......
# ['https://bj.lianjia.com/zufang/BJ1971246510091796480.html', '中央别墅区', '康营家园五区', '51.00', '4237', '南', '1室1厅1卫']
# ['https://bj.lianjia.com/zufang/BJ1724371580814884864.html', '朝阳公园', '棕榈泉国际公寓', '333.00', '62500', '南', '4室2厅3卫']
# ['https://bj.lianjia.com/zufang/BJ1947536663886430208.html', '双井', '百环家园', '111.73', '7800', '东北', '2室1厅1卫']
# ['https://bj.lianjia.com/zufang/BJ1883151026354126848.html', '酒仙桥', '驼房营南里', '76.00', '6000', '西北', '3室1厅1卫']
# ['https://bj.lianjia.com/zufang/BJ1734428396592562176.html', '定福庄', '定福庄南里1号院', '65.00', '5400', '南北', '2室1厅1卫']
# ['https://bj.lianjia.com/zufang/BJ1747633831805976576.html', '双桥', '康城别墅二期', '240.00', '16800', '南北', '4室2厅4卫']
# ['https://bj.lianjia.com/zufang/BJ1917886130385059840.html', '北苑', '华发颐园', '59.53', '5200', '西', '1室1厅1卫']
# ['https://bj.lianjia.com/zufang/BJ1787061459142836224.html', '朝阳其它', '华樾国际', '89.84', '7700', '南北', '3室1厅1卫']
# ['https://bj.lianjia.com/zufang/BJ1746894072414470144.html', '常营', '北京新天地四期', '93.00', '6000', '南', '2室1厅1卫']
# ['https://bj.lianjia.com/zufang/BJ1764580832015548416.html', '望京', '世安家园', '66.33', '5900', '南北', '2室1厅1卫']
# ['https://bj.lianjia.com/zufang/BJ1917986529620262912.html', '豆各庄', '京城雅居', '160.40', '9600', '南北', '4室2厅2卫']
# ['https://bj.lianjia.com/zufang/BJ2007661806486552576.html', '百子湾', '观音景园二期', '64.39', '4300', '南', '1室1厅1卫']
# ['https://bj.lianjia.com/zufang/BJ1765256244743897088.html', '农展馆', '高尔夫国际公寓', '308.00', '48000', '南北', '4室2厅3卫']
# ['https://bj.lianjia.com/zufang/BJ1768206543607562240.html', '双井', '富力城C区', '226.00', '23000', '东南南北', '4室2厅3卫']
# ['https://bj.lianjia.com/zufang/BJ1766296908101320704.html', '望京', '绿地中心', '263.32', '55000', '南', '2室2厅1卫']
# ['https://bj.lianjia.com/zufang/BJ1774015260341043200.html', '国展', '柳芳南里', '45.00', '7000', '南', '1室1厅1卫']
# ['https://bj.lianjia.com/zufang/BJ1778774880037109760.html', '大望路', '西大望路铁西宿舍', '50.11', '6300', '南北', '2室1厅1卫']
# ['https://bj.lianjia.com/zufang/BJ1780213795298213888.html', '奥林匹克公园', '景龙国际', '67.66', '6800', '东', '1室1厅1卫']
# ['https://bj.lianjia.com/zufang/BJ1780856735745966080.html', '望京', '融科橄榄城一期', '233.92', '23000', '南北', '4室2厅2卫']
# ['https://bj.lianjia.com/zufang/BJ1782271596354863104.html', '欢乐谷', '北京华侨城1号院', '147.00', '13800', '南', '3室2厅2卫']
# ['https://bj.lianjia.com/zufang/BJ1918175693649215488.html', '朝阳公园', '丽水嘉园', '74.00', '9000', '南', '1室1厅1卫']
# ['https://bj.lianjia.com/zufang/BJ1785540072154595328.html', '燕莎', '京润水上花园别墅', '98.75', '22500', '南北', '3室1厅2卫']
# ['https://bj.lianjia.com/zufang/BJ1786630700330385408.html', '建国门外', '华侨村', '135.00', '15000', '东南', '3室2厅2卫']
# ['https://bj.lianjia.com/zufang/BJ1852282915983982592.html', '三元桥', '凤凰城一期', '76.92', '13000', '西北', '1室1厅1卫']
# 本页共爬取到 24 条有效数据。
# ---------------------------
# 准备爬取第 3 页......
# 正在获取页面内容......
# ['https://bj.lianjia.com/zufang/BJ1839263721021505536.html', '燕莎', '霞光里30号院', '62.65', '6800', '东南西北', '2室1厅1卫']
# ['https://bj.lianjia.com/zufang/BJ1754740611107258368.html', '北工大', '平乐园小区', '47.00', '5550', '南北', '2室1厅1卫']
# ['https://bj.lianjia.com/zufang/BJ1839956619652235264.html', 'CBD', '建外soho东区', '247.00', '45000', '西北', '3室2厅2卫']
# ['https://bj.lianjia.com/zufang/BJ1852282915983982592.html', '三元桥', '凤凰城一期', '76.92', '13000', '西北', '1室1厅1卫']
# ['https://bj.lianjia.com/zufang/BJ1843999323860238336.html', '红庙', '纽约豪园', '190.05', '27500', '东南', '3室2厅2卫']
# ['https://bj.lianjia.com/zufang/BJ1843999532971458560.html', '东大桥', '世贸国际公寓', '260.00', '38000', '南北', '3室2厅2卫']
# ['https://bj.lianjia.com/zufang/BJ1845385601331757056.html', '亚运村', '紫玉山庄', '332.00', '90000', '西南北', '5室3厅5卫']
# ['https://bj.lianjia.com/zufang/BJ1696099039063310336.html', '和平里', '和平西街1号院', '83.00', '7999', '西北', '2室1厅1卫']
# ['https://bj.lianjia.com/zufang/BJ2016691183857696768.html', '石佛营', '石佛营东里128号院', '99.09', '7000', '南', '2室1厅1卫']
# ['https://bj.lianjia.com/zufang/BJ1756675212205621248.html', '芍药居', '隆远阁', '56.80', '8000', '东北', '1室1厅1卫']
# ['https://bj.lianjia.com/zufang/BJ1847181876897251328.html', '北工大', '磨房南里', '44.01', '5500', '东', '1室1厅1卫']
# ['https://bj.lianjia.com/zufang/BJ1850144762808500224.html', '红庙', '华业玫瑰东方', '167.00', '18000', '南北', '3室1厅2卫']
# ['https://bj.lianjia.com/zufang/BJ1763417882810646528.html', '四惠', '壹线国际', '45.00', '5665', '南', '1室0厅1卫']
# ['https://bj.lianjia.com/zufang/BJ1851169460216397824.html', '亚运村', '保利金泉', '87.39', '8500', '东', '1室1厅1卫']
# ['https://bj.lianjia.com/zufang/BJ1851549698796552192.html', '三元桥', '时间国际中心 ', '193.45', '21802', '东北', '3室1厅0卫']
# ['https://bj.lianjia.com/zufang/BJ1851922995577094144.html', '朝青', '珠江罗马嘉园东区', '119.00', '14000', '西南', '3室2厅2卫']
# ['https://bj.lianjia.com/zufang/BJ1604358144522190848.html', '定福庄', '鲁班大厦', '141.52', '11000', '南北', '3室1厅2卫']
# ['https://bj.lianjia.com/zufang/BJ1662673439313362944.html', '亚运村小营', '鸿华家园', '515.78', '75000', '东南北', '5室2厅5卫']
# ['https://bj.lianjia.com/zufang/BJ1698656741283069952.html', '朝青', '华纺易城', '181.53', '17700', '东南北', '4室2厅2卫']
# ['https://bj.lianjia.com/zufang/BJ1703047231323504640.html', '亮马桥', '牛王庙', '35.46', '5400', '东南', '1室1厅1卫']
# ['https://bj.lianjia.com/zufang/BJ1724371580814884864.html', '朝阳公园', '棕榈泉国际公寓', '333.00', '62500', '南', '4室2厅3卫']
# ['https://bj.lianjia.com/zufang/BJ1758712403878477824.html', '百子湾', '沿海赛洛城二期', '93.66', '7800', '东北', '2室1厅1卫']
# ['https://bj.lianjia.com/zufang/BJ1734428396592562176.html', '定福庄', '定福庄南里1号院', '65.00', '5400', '南北', '2室1厅1卫']
# ['https://bj.lianjia.com/zufang/BJ1747633831805976576.html', '双桥', '康城别墅二期', '240.00', '16800', '南北', '4室2厅4卫']
# ['https://bj.lianjia.com/zufang/BJ1746894072414470144.html', '常营', '北京新天地四期', '93.00', '6000', '南', '2室1厅1卫']
# 本页共爬取到 25 条有效数据。
# ---------------------------
# 准备爬取第 4 页......
# 正在获取页面内容......
# ['https://bj.lianjia.com/zufang/BJ1763907087538061312.html', '百子湾', '美利山', '81.94', '7004', '东', '2室1厅1卫']
# ['https://bj.lianjia.com/zufang/BJ1904073293535641600.html', '西坝河', '西坝河南里', '56.41', '5500', '南', '1室1厅1卫']
# ['https://bj.lianjia.com/zufang/BJ1904030321871945728.html', '双井', '时代国际嘉园', '98.76', '9300', '南', '2室1厅1卫']
# ['https://bj.lianjia.com/zufang/BJ1904410734519910400.html', '北苑', '城锦苑', '62.36', '6300', '南', '1室1厅1卫']
# ['https://bj.lianjia.com/zufang/BJ1835588758641049600.html', '东大桥', '北京财富中心', '90.25', '16500', '南', '1室1厅1卫']
# ['https://bj.lianjia.com/zufang/BJ1904818320759062528.html', '双井', '富力城D区', '277.21', '41000', '西南北', '4室2厅3卫']
# ['https://bj.lianjia.com/zufang/BJ1904850570787684352.html', '朝青', '宝成雅园', '98.00', '8900', '西南', '2室1厅1卫']
# ['https://bj.lianjia.com/zufang/BJ2014929731786375168.html', '东坝', '汇景苑二区', '80.51', '5400', '南北', '2室1厅1卫']
# ['https://bj.lianjia.com/zufang/BJ1908041204344291328.html', '常营', '柏林爱乐二期', '155.85', '11500', '南北', '4室2厅2卫']
# ['https://bj.lianjia.com/zufang/BJ1908028769537359872.html', '望京', '望花路西里', '82.90', '6900', '东南', '2室1厅1卫']
# ['https://bj.lianjia.com/zufang/BJ1907694139768569856.html', '工体', '光彩国际公寓', '217.00', '25000', '南西北', '3室2厅2卫']
# ['https://bj.lianjia.com/zufang/BJ1758867466999562240.html', '甜水园', '秀水园', '39.00', '5300', '南', '1室1厅1卫']
# ['https://bj.lianjia.com/zufang/BJ1908752188897755136.html', '惠新西街', '小关北里', '60.23', '6200', '南北', '2室1厅1卫']
# ['https://bj.lianjia.com/zufang/BJ1908440596406599680.html', '管庄', '烟厂宿舍', '40.00', '3500', '南', '1室1厅1卫']
# ['https://bj.lianjia.com/zufang/BJ1762404164387733504.html', '东大桥', '工体南路', '50.70', '8034', '东北', '2室1厅1卫']
# ['https://bj.lianjia.com/zufang/BJ1763905758690279424.html', '豆各庄', '富力又一城B区', '93.00', '6592', '东南北', '2室2厅1卫']
# ['https://bj.lianjia.com/zufang/BJ1909460356896391168.html', '奥林匹克公园', '汽修一厂宿舍', '57.08', '5500', '南北', '3室1厅1卫']
# ['https://bj.lianjia.com/zufang/BJ1909527871978733568.html', '亚运村', '润枫德尚苑', '123.00', '15800', '东北', '2室1厅1卫']
# ['https://bj.lianjia.com/zufang/BJ1762127316172931072.html', '国展', '静安里', '40.00', '5253', '东南', '1室1厅1卫']
# ['https://bj.lianjia.com/zufang/BJ1909964427231232000.html', '双井', '富力十号', '288.00', '63000', '东南北', '4室1厅3卫']
# ['https://bj.lianjia.com/zufang/BJ1909933782836707328.html', '双井', '广渠门外大街路北区', '41.23', '5500', '南北', '2室1厅2卫']
# ['https://bj.lianjia.com/zufang/BJ1910212819404455936.html', '首都机场', '首都机场南路西里', '57.01', '3700', '南北', '2室1厅1卫']
# ['https://bj.lianjia.com/zufang/BJ1762520437163556864.html', '亮马桥', '三源里街', '59.45', '7000', '东南', '2室1厅1卫']
# ['https://bj.lianjia.com/zufang/BJ1910995308238602240.html', '中央别墅区', '香江花园', '82.00', '140000', '南北', '5室2厅4卫']
# ['https://bj.lianjia.com/zufang/BJ1911001707731484672.html', '甜水园', '道家村', '60.00', '5300', '南北', '2室1厅1卫']
# ['https://bj.lianjia.com/zufang/BJ1911323831482449920.html', '东大桥', '山水铂宫 ', '246.00', '32000', '西西北', '4室2厅2卫']
# 本页共爬取到 26 条有效数据。
# ---------------------------
# 准备爬取第 5 页......
# 正在获取页面内容......
# ['https://bj.lianjia.com/zufang/BJ1908028769537359872.html', '望京', '望花路西里', '82.90', '6900', '东南', '2室1厅1卫']
# ['https://bj.lianjia.com/zufang/BJ1848987643585495040.html', '朝青', '华纺易城', '89.00', '8190', '南', '2室1厅1卫']
# ['https://bj.lianjia.com/zufang/BJ1907694139768569856.html', '工体', '光彩国际公寓', '217.00', '25000', '南西北', '3室2厅2卫']
# ['https://bj.lianjia.com/zufang/BJ1621456827134771200.html', '劲松', '农光里', '65.22', '5990', '东南', '2室1厅1卫']
# ['https://bj.lianjia.com/zufang/BJ1907651758692237312.html', '和平里', '和平街十四区', '54.19', '7500', '南北', '2室1厅1卫']
# ['https://bj.lianjia.com/zufang/BJ1776906107910881280.html', '双桥', '北花园小区3号院', '52.00', '4355', '南', '1室1厅1卫']
# ['https://bj.lianjia.com/zufang/BJ1908752188897755136.html', '惠新西街', '小关北里', '60.23', '6200', '南北', '2室1厅1卫']
# ['https://bj.lianjia.com/zufang/BJ1908440596406599680.html', '管庄', '烟厂宿舍', '40.00', '3500', '南', '1室1厅1卫']
# ['https://bj.lianjia.com/zufang/BJ1813418946561310720.html', '管庄', '北岸1292', '47.17', '4530', '南', '1室1厅1卫']
# ['https://bj.lianjia.com/zufang/BJ1909460356896391168.html', '奥林匹克公园', '汽修一厂宿舍', '57.08', '5500', '南北', '3室1厅1卫']
# ['https://bj.lianjia.com/zufang/BJ1909527871978733568.html', '亚运村', '润枫德尚苑', '123.00', '15800', '东北', '2室1厅1卫']
# ['https://bj.lianjia.com/zufang/BJ1910569242713915392.html', '建国门外', '地杰长安驿', '45.47', '6800', '南', '1室0厅1卫']
# ['https://bj.lianjia.com/zufang/BJ1909964427231232000.html', '双井', '富力十号', '288.00', '63000', '东南北', '4室1厅3卫']
# ['https://bj.lianjia.com/zufang/BJ1909933782836707328.html', '双井', '广渠门外大街路北区', '41.23', '5500', '南北', '2室1厅2卫']
# ['https://bj.lianjia.com/zufang/BJ1910212819404455936.html', '首都机场', '首都机场南路西里', '57.01', '3700', '南北', '2室1厅1卫']
# ['https://bj.lianjia.com/zufang/BJ1910995308238602240.html', '中央别墅区', '香江花园', '82.00', '140000', '南北', '5室2厅4卫']
# ['https://bj.lianjia.com/zufang/BJ1669262421786624000.html', '酒仙桥', '丽都壹号', '85.55', '9200', '南北', '2室1厅1卫']
# ['https://bj.lianjia.com/zufang/BJ1632664104898396160.html', '百子湾', '北京第二制药厂宿舍', '54.00', '5700', '东南', '2室1厅1卫']
# ['https://bj.lianjia.com/zufang/BJ1911001707731484672.html', '甜水园', '道家村', '60.00', '5300', '南北', '2室1厅1卫']
# ['https://bj.lianjia.com/zufang/BJ1830398455369957376.html', '潘家园', '潘家园东里', '64.67', '5890', '南', '2室1厅1卫']
# ['https://bj.lianjia.com/zufang/BJ1911323831482449920.html', '东大桥', '山水铂宫 ', '246.00', '32000', '西西北', '4室2厅2卫']
# ['https://bj.lianjia.com/zufang/BJ1912440937238233088.html', '西坝河', '西坝河东里', '61.00', '6300', '南北', '2室1厅1卫']
# ['https://bj.lianjia.com/zufang/BJ1849287912168882176.html', '东坝', '首开畅颐园', '88.39', '5600', '东南西北', '2室1厅1卫']
# 本页共爬取到 23 条有效数据。
# ---------------------------
# 共爬取到 123 条有效数据。
# 去重后还有 106 条数据。
# 正在保存到 CSV 文件中......
# 数据已成功保存到 CSV 文件。
